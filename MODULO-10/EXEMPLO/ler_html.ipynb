# %%
import pandas as pd

# %%
html = pd.read_html('https://pt.wikipedia.org/wiki/Discografia_de_Avril_Lavigne')

# %%
html

# %%
df = pd.DataFrame(html[1])
df.shape
# Out:
# (7, 19)

# %%
df
# Out:
#     Ano                                              Álbum Melhor Posição[24]  \
#     Ano                                              Álbum                CAN
# 0  2002  Let Go Lançamento: 4 de Junho de 2002 Formatos...                  1
# 1  2004  Under My Skin Lançamento: 25 de Maio de 2004 F...                  1
# 2  2007  The Best Damn Thing Lançamento: 17 de abril de...                  1
# 3  2011  Goodbye Lullaby Lançamento: 8 de março de 2011...                  2
# 4  2013  Avril Lavigne Lançamento: 5 de novembro de 201...                  4
# 5  2019  Head Above Water Lançamento: 15 de fevereiro d...                  5
# 6  2022  Love Sux Lançamento: 25 de fevereiro de 2022 F...                  3
#
#                                                                           \
#   EUA RU[25] BRA GRE AUS NZL MEX ESP JAP ALE ITA[26] FRA SUE AUT NOR[27]
# 0   2      1   1   2   2   1   1   2   1   2       6   2   6   2       3
# ...

# %%
import pandas as pd
import numpy as np

# %%
iris_df = pd.read_csv('Iris.csv')

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
amostra_simples = iris_df.sample(30, replace=True)

# %%
amostra_simples.shape
# Out:
# (30, 6)

# %%
def amostra_sistematica(df, step):
    indice = np.arange(1,len(df), step=step)
    amostra = df.iloc[indice]
    return amostra

# %%
amostragem = amostra_sistematica(iris_df, 3)
amostragem
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 7      8            5.0           3.4            1.5           0.2
# 10    11            5.4           3.7            1.5           0.2
# 13    14            4.3           3.0            1.1           0.1
# 16    17            5.4           3.9            1.3           0.4
# 19    20            5.1           3.8            1.5           0.3
# 22    23            4.6           3.6            1.0           0.2
# 25    26            5.0           3.0            1.6           0.2
# 28    29            5.2           3.4            1.4           0.2
# 31    32            5.4           3.4            1.5           0.4
# 34    35            4.9           3.1            1.5           0.1
# 37    38            4.9           3.1            1.5           0.1
# ...

# %%
amostragem.shape
# Out:
# (50, 6)

# %%
amostra_estratificada = iris_df.groupby('Species', group_keys=False).apply(lambda x: x.sample(3))

# %%
amostra_estratificada
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 12    13            4.8           3.0            1.4           0.1
# 6      7            4.6           3.4            1.4           0.3
# 5      6            5.4           3.9            1.7           0.4
# 68    69            6.2           2.2            4.5           1.5
# 93    94            5.0           2.3            3.3           1.0
# 59    60            5.2           2.7            3.9           1.4
# 136  137            6.3           3.4            5.6           2.4
# 144  145            6.7           3.3            5.7           2.5
# 102  103            7.1           3.0            5.9           2.1
#
#              Species
# 12       Iris-setosa
# 6        Iris-setosa
# 5        Iris-setosa
# 68   Iris-versicolor
# 93   Iris-versicolor
# 59   Iris-versicolor
# 136   Iris-virginica
# 144   Iris-virginica
# 102   Iris-virginica

# %%
sales_df = pd.read_csv('../Exercício Bloco2/sales.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11104/3820011248.py in <module>
# ----> 1 sales_df = pd.read_csv('../Exercício Bloco2/sales.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/valdirdpg/curso-dnc/blob/master/Aula2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **AULA 2 - Importar dados tabulares e extrair informações gerais**
#
# ---
#
# > Lendo e escrevendo dados tabulares...
#
# ![Captura de tela de 2022-08-17 14-30-34.png](data:image/png;base64,...)

# %% [markdown]
# > **SITUAÇÃO PROBLEMA**
#
# Vamos supor que você seja dono de um banco em Taiwan que oferta serviço de crédito. Você tem em mãos uma tabela em excel com dados dos clientes que contrataram o serviço de crédito.
#
# `Objetivo`: apresentar um panorama consolidado sobre a situação dos clientes no banco para o restante da empresa.
#
# **PASSO 1: ENTENDER OS METADADOS DO DATAFRAME:**
#
# ![DATA_ANALYSIS.drawio (2).png](data:image/png;base64,...)

# %%
# Importando a biblioteca

import pandas as pd

# %%
# Lendo dados tabulares

credit = pd.read_csv("/content/credit_card_clients.csv")

# %% [markdown]
# Metadados do DataFrame:
#
# O conjunto de dados `credit` contém informações sobre pagamentos, fatores demográficos, dados de crédito, histórico de pagamentos e extratos de contas de clientes de cartão de crédito em Taiwan de abril de 2005 a setembro de 2005.
#
# O DataFrame contém 25 variáveis:
#
# - `ID`: ID de cada cliente.
#
# - `LIMIT_BAL`: Valor do crédito concedido em NT (New Taiwan) dólar (inclui crédito individual e familiar/complementar).
#
# - `SEXO`: Gênero (1=masculino, 2=feminino).
#
# - `EDUCAÇÃO`: (1 = pós-graduação, 2 = universidade, 3 = ensino médio, 4 = outros, 5 = desconhecido, 6 = desconhecido).
#
# - `CASAMENTO`: Estado civil (1=casado, 2=solteiro, 3=outros).
#
# - `IDADE`: Idade em anos.
#
# - `PAY_0`: Status de pagamento em setembro de 2005 .(-1=pagamento devido, 1=atraso de pagamento por um mês, 2=atraso de pagamento por dois meses, … 8=atraso de pagamento por oito meses, 9=atraso de pagamento por nove meses e acima).
#
# - `PAY_2`: Status de reembolso em agosto de 2005 (escala igual à acima).
#
# - `PAY_3`: Status de reembolso em julho de 2005 (escala igual à acima).
#
# - `PAY_4`: Status de reembolso em junho de 2005 (escala igual à acima).
#
# - `PAY_5`: Status de reembolso em maio de 2005 (escala igual à acima).
#
# - `PAY_6`: Status de reembolso em abril de 2005 (escala igual à acima).
#
# - `BILL_AMT1`: Valor do extrato da conta em setembro de 2005 (dólar NT).
#
# - `BILL_AMT2`: Valor do extrato da conta em agosto de 2005 (dólar NT).
#
# - `BILL_AMT3`: Valor do extrato da conta em julho de 2005 (dólar NT).
#
# - `BILL_AMT4`: Valor do extrato da conta em junho de 2005 (dólar NT).
#
# - `BILL_AMT5`: Valor do extrato da conta em maio de 2005 (dólar NT).
#
# - `BILL_AMT6`: Valor do extrato da conta em abril de 2005 (dólar NT).
#
# - `PAY_AMT1`: Valor do pagamento anterior em setembro de 2005 (dólar NT).
#
# - `PAY_AMT2`: Valor do pagamento anterior em agosto de 2005 (dólar NT).
#
# - `PAY_AMT3`: Valor do pagamento anterior em julho de 2005 (dólar NT).
#
# - `PAY_AMT4`: Valor do pagamento anterior em junho de 2005 (dólar NT).
#
# - `PAY_AMT5`: Valor do pagamento anterior em maio de 2005 (dólar NT).
#
# - `PAY_AMT6`: Valor do pagamento anterior em abril de 2005 (dólar NT).
#
# - `default.payment.next.month`: Pagamento padrão (1=sim, 0=não).

# %% [markdown]
# > Extraindo informações gerais do *DataFrame*...
#
# ```
# info()
#
# head()
#
# tail()
#
# shape
#
# rename()
#
# drop()
#
# ```

# %%
credit.info()   # Extraindo informações técnicas de um DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# O método `info()` fornece informações técnicas sobre um determinado DataFrame:
#
# - `class 'pandas.core.frame.DataFrame`: confirma que o objeto trata-se de um DataFrame;
# - `RangeIndex: 30000 entries, 0 to 29999`: existem 30mil entradas, ou seja, 30mil linhas;
# - `Non-Null Count`: mostra os valores ausentes. Neste caso, temos 30mil valores não nulos para cada coluna;
# - `Dtype`: identifica o tipo de dado (strings, float, integer...).
# - `Memory usage`: fornece a quantidade de memória RAM usada para armazenar o df.

# %%
# Visualizando as primeiras linhas de um DataFrame 

credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
# Visualizando as últimas linhas de um DataFrame

credit.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [5 rows x 25 columns]

# %%
credit.shape   # Consultando as dimensões de um DataFrame
# Out:
# (30000, 25)

# %% [markdown]
# - **Observação**
#
# `O comando shape é um atributo de um pandas Series ou DataFrame contendo o número de linhas e colunas. Portanto não use parênteses.`
#
# Return: *(nrows, ncolumns).*

# %%
# Renomeando as colunas

credit_renamed = credit.rename(columns = {'LIMIT_BAL':'valor_credito',
                                          'SEX':'sexo',
                                          'EDUCATION':'nivel_escolaridade',
                                          'MARRIAGE':'estado_civil',
                                          'AGE':'idade',
                                          'PAY_0':'status_pag_set_2005',
                                          'PAY_2':'status_pag_ago_2005',
                                          'PAY_3':'status_pag_jul_2005',
                                          'PAY_4':'status_pag_jun_2005',
                                          'PAY_5':'status_pag_mai_2005',
                                          'PAY_6':'status_pag_abr_2005',
                                          'BILL_AMT1':'extrato_set_2005',
                                          'BILL_AMT2':'extrato_ago_2005',
                                          'BILL_AMT3':'extrato_jul_2005',
                                          'BILL_AMT4':'extrato_jun_2005',
                                          'BILL_AMT5':'extrato_mai_2005',
                                          'BILL_AMT6':'extrato_abr_2005',
                                          'PAY_AMT1':'valor_pag_set_2005',
                                          'PAY_AMT2':'valor_pag_ago_2005',
                                          'PAY_AMT3':'valor_pag_jul_2005',
                                          'PAY_AMT4':'valor_pag_jun_2005',
                                          'PAY_AMT5':'valor_pag_mai_2005',
                                          'PAY_AMT6':'valor_pag_abr_2005'
})

# %%
# Excluindo uma coluna do DataFrame

credit_renamed.drop(["default payment next month"], axis=1, inplace=True)

# %%
credit_renamed
# Out:
#           ID  valor_credito  sexo  nivel_escolaridade  estado_civil  idade  \
# 0          1          20000     2                   2             1     24
# 1          2         120000     2                   2             2     26
# 2          3          90000     2                   2             2     34
# 3          4          50000     2                   2             1     37
# 4          5          50000     1                   2             1     57
# ...      ...            ...   ...                 ...           ...    ...
# 29995  29996         220000     1                   3             1     39
# 29996  29997         150000     1                   3             2     43
# 29997  29998          30000     1                   2             2     37
# 29998  29999          80000     1                   3             1     41
# 29999  30000          50000     1                   2             1     46
#
#        status_pag_set_2005  status_pag_ago_2005  status_pag_jul_2005  \
# 0                        2                    2                   -1
# 1                       -1                    2                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                       -1                    0                   -1
# ...                    ...                  ...                  ...
# 29995                    0                    0                    0
# 29996                   -1                   -1                   -1
# 29997                    4                    3                    2
# 29998                    1                   -1                    0
# 29999                    0                    0                    0
#
#        status_pag_jun_2005  ...  extrato_jul_2005  extrato_jun_2005  \
# 0                       -1  ...               689                 0
# 1                        0  ...              2682              3272
# 2                        0  ...             13559             14331
# 3                        0  ...             49291             28314
# 4                        0  ...             35835             20940
# ...                    ...  ...               ...               ...
# 29995                    0  ...            208365             88004
# 29996                   -1  ...              3502              8979
# 29997                   -1  ...              2758             20878
# 29998                    0  ...             76304             52774
# 29999                    0  ...             49764             36535
#
#        extrato_mai_2005  extrato_abr_2005  valor_pag_set_2005  \
# 0                     0                 0                   0
# 1                  3455              3261                   0
# 2                 14948             15549                1518
# 3                 28959             29547                2000
# 4                 19146             19131                2000
# ...                 ...               ...                 ...
# 29995             31237             15980                8500
# 29996              5190                 0                1837
# 29997             20582             19357                   0
# 29998             11855             48944               85900
# 29999             32428             15313                2078
#
#        valor_pag_ago_2005  valor_pag_jul_2005  valor_pag_jun_2005  \
# 0                     689                   0                   0
# 1                    1000                1000                1000
# 2                    1500                1000                1000
# 3                    2019                1200                1100
# 4                   36681               10000                9000
# ...                   ...                 ...                 ...
# 29995               20000                5003                3047
# 29996                3526                8998                 129
# 29997                   0               22000                4200
# 29998                3409                1178                1926
# 29999                1800                1430                1000
#
#        valor_pag_mai_2005  valor_pag_abr_2005
# 0                       0                   0
# 1                       0                2000
# 2                    1000                5000
# 3                    1069                1000
# 4                     689                 679
# ...                   ...                 ...
# 29995                5000                1000
# 29996                   0                   0
# 29997                2000                3100
# 29998               52964                1804
# 29999                1000                1000
#
# [30000 rows x 24 columns]

# %% [markdown]
# - **Observação**
#
# O comando `axis` identifica se a operação deve ser realizada na linha ou coluna. 0 para linha e 1 para coluna.
#
# O parâmetro `inplace` substitui a ação no DataFrame original.

# %%
# Escrevendo dados tabulares

credit_renamed.to_excel("clientes_credito.xlsx")

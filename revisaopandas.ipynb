# %% [markdown]
# <a href="https://colab.research.google.com/github/valdirdpg/curso-dnc/blob/valdir-exercicio/revisaopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
igm = pd.read_csv('/content/igm_modificado.csv')

# %%
igm
# Out:
#             regiao estado                municipio  codigo_mun  capital  \
# 0          SUDESTE     SP                 ILHABELA     3520400        0
# 1          SUDESTE     SP      SANTANA DE PARNAIBA     3547304        0
# 2              SUL     SC                BOMBINHAS     4202453        0
# 3          SUDESTE     SP    SAO BERNARDO DO CAMPO     3548708        0
# 4     CENTRO-OESTE     DF                 BRASILIA     5300108        1
# ...            ...    ...                      ...         ...      ...
# 5565         NORTE     TO             RIO DOS BOIS     1718709        0
# 5566         NORTE     TO       AXIXA DO TOCANTINS     1702901        0
# 5567         NORTE     TO               FILADELFIA     1707702        0
# 5568         NORTE     TO  PONTE ALTA DO TOCANTINS     1717909        0
# 5569         NORTE     TO             SILVANOPOLIS     1720655        0
#
#                 porte  populacao      area densidade_dem           pib  ...  \
# ...

# %%
igm.describe().T
# Out:
#                               count          mean           std           min  \
# codigo_mun                   5570.0  3.253591e+06  9.849103e+05  1.100015e+06
# capital                      5570.0  4.847397e-03  6.946053e-02  0.000000e+00
# pib                          5570.0  9.544801e+05  9.502661e+06  9.678440e+03
# pib_pc                       5570.0  1.737448e+04  2.013334e+04  3.241290e+03
# participacao_transf_receita  4893.0  8.231657e+01  1.127214e+01  0.000000e+00
# servidores                   5233.0  7.713249e+02  3.209756e+03  1.000000e+00
# comissionados                5570.0  9.637127e+01  2.349945e+02  0.000000e+00
# perc_pop_econ_ativa          5565.0  9.365031e-01  1.786402e-01  2.900000e-01
# taxa_empreendedorismo        5570.0  2.509390e-01  9.801439e-02  0.000000e+00
# anos_estudo_empreendedor     5570.0  6.124378e+00  1.462946e+00  0.000000e+00
# jornada_trabalho             5570.0  4.141401e+01  5.193799e+00  0.000000e+00
# ...

# %%
regiao = igm.groupby('regiao').size().reset_index(name='qtd')

# %%
regiao
# Out:
#          regiao   qtd
# 0  CENTRO-OESTE   467
# 1      NORDESTE  1794
# 2         NORTE   450
# 3       SUDESTE  1668
# 4           SUL  1191

# %%
regiao
# Out:
#          regiao   qtd
# 0  CENTRO-OESTE   467
# 1      NORDESTE  1794
# 2         NORTE   450
# 3       SUDESTE  1668
# 4           SUL  1191

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=regiao, y='regiao', x='qtd')
# Out:
# <AxesSubplot:xlabel='qtd', ylabel='regiao'>

# %%
igm.sample(10)
# Out:
#             regiao estado                  municipio  codigo_mun  capital  \
# 2378      NORDESTE     CE                MORADA NOVA     2308708        0
# 5044      NORDESTE     PI                   BOA HORA     2201770        0
# 1707      NORDESTE     RN             SEVERIANO MELO     2413607        0
# 2189       SUDESTE     MG                  MARLIERIA     3140308        0
# 3504  CENTRO-OESTE     MT                  QUERENCIA     5107065        0
# 1664  CENTRO-OESTE     MT         PONTAL DO ARAGUAIA     5106653        0
# 162            SUL     RS                     ESTEIO     4307708        0
# 2091       SUDESTE     MG                     CAIANA     3110103        0
# 615            SUL     PR  SANTA TEREZINHA DE ITAIPU     4124053        0
# 3247         NORTE     TO     SAO BENTO DO TOCANTINS     1720101        0
#
#                 porte populacao       area densidade_dem         pib  ...  \
# 2378      Médio porte    61,722   2,778.58          22.3   627248.13  ...
# ...

# %%
igm['densidade_dem'].fillna('0', inplace=True)
igm['densidade_dem'] = pd.to_numeric(igm.densidade_dem, errors='coerce').astype(float)

# %%
igm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   regiao                       5570 non-null   object
#  1   estado                       5570 non-null   object
#  2   municipio                    5570 non-null   object
#  3   codigo_mun                   5570 non-null   int64
#  4   capital                      5570 non-null   int64
#  5   porte                        5570 non-null   object
#  6   populacao                    5570 non-null   object
#  7   area                         5570 non-null   object
#  8   densidade_dem                5475 non-null   float64
#  9   pib                          5570 non-null   float64
#  10  pib_pc                       5570 non-null   float64
#  11  participacao_transf_receita  4893 non-null   float64
#  12  servidores                   5233 non-null   float64
# ...

# %%
capital = igm[igm['capital']== 1]

# %%
capital
# Out:
#             regiao estado       municipio  codigo_mun  capital         porte  \
# 4     CENTRO-OESTE     DF        BRASILIA     5300108        1  Grande porte
# 14         SUDESTE     ES         VITORIA     3205309        1  Grande porte
# 16         SUDESTE     SP       SAO PAULO     3550308        1  Grande porte
# 30             SUL     RS    PORTO ALEGRE     4314902        1  Grande porte
# 38         SUDESTE     MG  BELO HORIZONTE     3106200        1  Grande porte
# 61             SUL     PR        CURITIBA     4106902        1  Grande porte
# 77        NORDESTE     CE       FORTALEZA     2304400        1  Grande porte
# 88         SUDESTE     RJ  RIO DE JANEIRO     3304557        1  Grande porte
# 118   CENTRO-OESTE     MS    CAMPO GRANDE     5002704        1  Grande porte
# 158   CENTRO-OESTE     MT          CUIABA     5103403        1  Grande porte
# 200            SUL     SC   FLORIANOPOLIS     4205407        1  Grande porte
# ...

# %%
capital = capital.groupby('estado').agg({'densidade_dem':'max'}).reset_index()

# %%
capital
# Out:
#    estado  densidade_dem
# 0      AC           38.0
# 1      AL            0.0
# 2      AM          158.1
# 3      AP           62.1
# 4      BA            0.0
# 5      CE            0.0
# 6      DF          444.7
# 7      ES            0.0
# 8      GO            0.0
# 9      MA            0.0
# 10     MG            0.0
# 11     MS           97.2
# 12     MT          157.7
# 13     PA            0.0
# 14     PB            0.0
# 15     PE            0.0
# 16     PI          584.9
# 17     PR            0.0
# 18     RJ            0.0
# 19     RN            0.0
# 20     RO           12.6
# 21     RR           50.0
# 22     RS            0.0
# 23     SC          623.7
# 24     SE            0.0
# 25     SP            0.0
# 26     TO          102.9

# %%
plt.figure(figsize=(10,5))
igm.regiao.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
igm.pib.value_counts()
# Out:
# 110143.27     2
# 3256711.64    1
# 428357.86     1
# 30757.81      1
# 321961.21     1
#              ..
# 71888.52      1
# 506700.47     1
# 226549.05     1
# 77677.53      1
# 77734.86      1
# Name: pib, Length: 5569, dtype: int64

# %%
igm.isnull().sum()
# Out:
# regiao                            0
# estado                            0
# municipio                         0
# codigo_mun                        0
# capital                           0
# porte                             0
# populacao                         0
# area                              0
# densidade_dem                     0
# pib                               0
# pib_pc                            0
# participacao_transf_receita     677
# servidores                      337
# comissionados                     0
# comissionados_por_servidor        0
# perc_pop_econ_ativa               5
# taxa_empreendedorismo             0
# anos_estudo_empreendedor          0
# jornada_trabalho                  0
# gasto_pc_saude                  689
# hab_p_medico                    619
# exp_vida                          5
# gasto_pc_educacao               690
# exp_anos_estudo                   5
# nota_ciencias                    12
# nota_humanas                     12
# ...

# %%
correlacao = igm['comissionados'].corr(igm['gasto_pc_educacao'])
correlacao
# Out:
# -0.03134449676465893

# %%
capital.densidade_dem.hist()
# Out:
# <AxesSubplot:>

# %%
medico_habitante = igm['hab_p_medico']
sns.kdeplot(medico_habitante)
# Out:
# <AxesSubplot:xlabel='hab_p_medico', ylabel='Density'>

# %%
gp_educacao = igm['gasto_pc_educacao']

# %%
sns.kdeplot(gp_educacao)
# Out:
# <AxesSubplot:xlabel='gasto_pc_educacao', ylabel='Density'>

# %%
import numpy as np

dados = np.random.normal(size=1000)
plt.hist(dados, bins=10)
plt.show()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima
from xgboost

# %%
energia = pd.read_excel('energy.xlsx', index_col='DATE')
energia.head()
# Out:
#              energy
# DATE
# 1985-01-01  71.5920
# 1985-02-01  69.7870
# 1985-03-01  61.6790
# 1985-04-01  56.7479
# 1985-05-01  54.6165

# %%
energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 408 entries, 1985-01-01 to 2018-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   energy  408 non-null    float64
# dtypes: float64(1)
# memory usage: 6.4 KB

# %%
energia.columns = ['producao']
energia
# Out:
#             producao
# DATE
# 1985-01-01   71.5920
# 1985-02-01   69.7870
# 1985-03-01   61.6790
# 1985-04-01   56.7479
# 1985-05-01   54.6165
# ...              ...
# 2018-08-01  113.0449
# 2018-09-01  101.4058
# 2018-10-01   94.4922
# 2018-11-01  101.3895
# 2018-12-01  110.5936
#
# [408 rows x 1 columns]

# %%
energia.index.max(), energia.index.min()
# Out:
# (Timestamp('2018-12-01 00:00:00'), Timestamp('1985-01-01 00:00:00'))

# %%
energia.producao.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
resultado = seasonal_decompose(energia.producao)
fig = plt.figure(figsize=(15,6))
fig = resultado.plot();
fig.set_size_inches(15,8);
